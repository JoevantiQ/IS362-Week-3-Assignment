# %%
import pandas as pd
#importing panda for this assignment

# %%
#Miles measured from odometer per day
cumulative_miles = pd.Series(
    [55, 120, 190, 250, 310],
    index=["Day 1", "Day 2", "Day 3", "Day 4", "Day 5"]
)

cumulative_miles

# %%
daily_miles.iloc[0] = cumulative_miles.iloc[0]
daily_miles

# %%
bike_data = pd.DataFrame({
    "Cumulative Miles": cumulative_miles,
    "Miles Rode That Day": daily_miles
})

bike_data
